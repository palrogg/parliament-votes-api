# %% [markdown]
# # Get Votes
#
# Récupérer les votes des parlementaires actuels en JSON grâce à l’API du parlement
#
# http://ws-old.parlament.ch/
#
# «Pour le moment, les nouveaux services web ne sont pas encore disponibles. Nous sommes cependant certains que nous pourrons remédier à cette situation d’ici au troisième trimestre 2019.»
#
# Votes:
# http://ws-old.parlament.ch/votes/councillors
#
# Exemple de liste de votes:

# %% [markdown]
# http://ws-old.parlament.ch/votes/councillors/3055?legislativePeriodFiter=662

# %%
import pandas as pd
import json
import requests
from time import sleep
pd.set_option('display.max_colwidth', 999)

# %%
# df à actualiser avec 1_Get_Councillors.ipynb
df_councillors = pd.read_csv('councillors.csv')

# %%
# Problème pas résolu: pour une partie des parlementaires, 
# l'API utilise un "number" qui ne correspond pas à l'"id",
# et qui n'est pas fourni dans la liste "historic"

delay = 0
exception_list = []

for i, row in df_councillors.iterrows():
    print(i, row['firstName'], row['lastName'], row['id'])
    response = requests.get(f"http://ws-old.parlament.ch/votes/councillors/{row['id']}?format=json&lang=fr", headers={'Accept': 'application/json', 'Accept-Language': 'fr-CH, fr;q=0.9, en;q=0.8, de;q=0.7, *;q=0.5'})
    try:
        df = pd.DataFrame(response.json())
    except:
        print(f"JSON invalide pour {row['firstName']} {row['lastName']} (id: {row['id']})")
        print(f"Lien:\nhttp://ws-old.parlament.ch/votes/councillors/{row['id']}?format=json&lang=fr")
        exception_list.append(row['id'])
        continue

    # On aplatit le json
    affairs = df['affairVotes'].tolist()
    df_affair = pd.DataFrame(affairs)
    df_affair['decision'] = df_affair['councillorVote'].apply(lambda x: x['decision'])
    
    dfm = df.join(df_affair, rsuffix='_')
    del dfm['affairVotes']
    del dfm['councillorVote']
    
    # On enregistre
    dfm.to_csv('data/{}_votes.csv'.format(number))
    sleep(delay)
# Out:
# 0 Andreas Aebi 3867
# JSON invalide pour Andreas Aebi (id: 3867)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/3867?format=json&lang=fr
# 1 Matthias Aebischer 4049
# JSON invalide pour Matthias Aebischer (id: 4049)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4049?format=json&lang=fr
# 2 Thomas Aeschi 4053
# JSON invalide pour Thomas Aeschi (id: 4053)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4053?format=json&lang=fr
# 3 Evi Allemann 1131
# JSON invalide pour Evi Allemann (id: 1131)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/1131?format=json&lang=fr
# 4 Cesla Amarelle 4107
# JSON invalide pour Cesla Amarelle (id: 4107)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4107?format=json&lang=fr
# 5 Céline Amaudruz 4090
# JSON invalide pour Céline Amaudruz (id: 4090)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4090?format=json&lang=fr
# 6 Viola Amherd 1288
# JSON invalide pour Viola Amherd (id: 1288)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/1288?format=json&lang=fr
# 7 Adrian Amstutz 1135
# JSON invalide pour Adrian Amstutz (id: 1135)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/1135?format=json&lang=fr
# 8 Adrian Amstutz 1135
# JSON invalide pour Adrian Amstutz (id: 1135)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/1135?format=json&lang=fr
# 9 Josiane Aubert 3833
# JSON invalide pour Josiane Aubert (id: 3833)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/3833?format=json&lang=fr
# 10 Caspar Baader 404
# JSON invalide pour Caspar Baader (id: 404)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/404?format=json&lang=fr
# 11 Caspar Baader 404
# JSON invalide pour Caspar Baader (id: 404)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/404?format=json&lang=fr
# 12 Jacqueline Badran 4058
# JSON invalide pour Jacqueline Badran (id: 4058)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4058?format=json&lang=fr
# 13 Guillaume Barazzone 4138
# JSON invalide pour Guillaume Barazzone (id: 4138)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4138?format=json&lang=fr
# 14 Luc Barthassat 1289
# JSON invalide pour Luc Barthassat (id: 1289)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/1289?format=json&lang=fr
# 15 Martin Bäumle 1138
# JSON invalide pour Martin Bäumle (id: 1138)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/1138?format=json&lang=fr
# 16 Maria Bernasconi 350
# JSON invalide pour Maria Bernasconi (id: 350)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/350?format=json&lang=fr
# 17 Kathrin Bertschy 4102
# JSON invalide pour Kathrin Bertschy (id: 4102)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4102?format=json&lang=fr
# 18 Max Binder 15
# JSON invalide pour Max Binder (id: 15)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/15?format=json&lang=fr
# 19 Prisca Birrer-Heimo 4030
# JSON invalide pour Prisca Birrer-Heimo (id: 4030)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4030?format=json&lang=fr
# 20 Pirmin Bischof 3871
# JSON invalide pour Pirmin Bischof (id: 3871)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/3871?format=json&lang=fr
# 21 Christoph Blocher 21
# JSON invalide pour Christoph Blocher (id: 21)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/21?format=json&lang=fr
# 22 Thomas Böhni 4050
# JSON invalide pour Thomas Böhni (id: 4050)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4050?format=json&lang=fr
# 23 Roland F. Borer 26
# JSON invalide pour Roland F. Borer (id: 26)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/26?format=json&lang=fr
# 24 Toni Bortoluzzi 28
# JSON invalide pour Toni Bortoluzzi (id: 28)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/28?format=json&lang=fr
# 25 Jacques Bourgeois 3872
# JSON invalide pour Jacques Bourgeois (id: 3872)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/3872?format=json&lang=fr
# 26 Heinz Brand 4067
# JSON invalide pour Heinz Brand (id: 4067)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4067?format=json&lang=fr
# 27 Toni Brunner 307
# JSON invalide pour Toni Brunner (id: 307)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/307?format=json&lang=fr
# 28 Roland Rino Büchel 4025
# JSON invalide pour Roland Rino Büchel (id: 4025)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4025?format=json&lang=fr
# 29 Jakob Büchler 1104
# JSON invalide pour Jakob Büchler (id: 1104)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/1104?format=json&lang=fr
# 30 André Bugnon 453
# JSON invalide pour André Bugnon (id: 453)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/453?format=json&lang=fr
# 31 Christine Bulliard-Marbach 4101
# JSON invalide pour Christine Bulliard-Marbach (id: 4101)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4101?format=json&lang=fr
# 32 Yannick Buttet 4086
# JSON invalide pour Yannick Buttet (id: 4086)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4086?format=json&lang=fr
# 33 Martin Candinas 4070
# JSON invalide pour Martin Candinas (id: 4070)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/4070?format=json&lang=fr
# 34 Marina Carobbio Guscetti 3830
# JSON invalide pour Marina Carobbio Guscetti (id: 3830)
# Lien:
# http://ws-old.parlament.ch/votes/councillors/3830?format=json&lang=fr
# 35 Andrea Caroni 4075
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-fa95b0266eb9> in <module>
#       6 for i, row in df_councillors.iterrows():
#       7     print(i, row['firstName'], row['lastName'], row['id'])
# ----> 8     response = requests.get(f"http://ws-old.parlament.ch/votes/councillors/{row['id']}?format=json&lang=fr", headers={'Accept': 'application/json', 'Accept-Language': 'fr-CH, fr;q=0.9, en;q=0.8, de;q=0.7, *;q=0.5'})
#       9     try:
#      10         df = pd.DataFrame(response.json())
#
# ~/.virtualenvs/dj/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/.virtualenvs/dj/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/.virtualenvs/dj/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/.virtualenvs/dj/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/.virtualenvs/dj/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/.virtualenvs/dj/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# ~/.virtualenvs/dj/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.virtualenvs/dj/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.virtualenvs/dj/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in getresponse(self)
#    1320         try:
#    1321             try:
# -> 1322                 response.begin()
#    1323             except ConnectionError:
#    1324                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
